# %%
import pandas as pd
import numpy as np
import torch

# %%
class Feedforward(torch.nn.Module):
        def __init__(self, input_size, hidden_size, dropout):
            super(Feedforward, self).__init__()
            self.input_size = input_size
            self.hidden_size  = hidden_size
            self.fc1 = torch.nn.Linear(self.input_size, self.hidden_size)
            self.fc2 = torch.nn.Linear(self.hidden_size, self.hidden_size)
            self.fc3 = torch.nn.Linear(self.hidden_size, self.hidden_size)
            self.fc4 = torch.nn.Linear(self.hidden_size, self.hidden_size)
            self.fc5 = torch.nn.Linear(self.hidden_size, self.hidden_size)
            #self.relu = torch.nn.ReLU()
            self.relu = torch.nn.LeakyReLU(0.1)
            self.fc_out = torch.nn.Linear(self.hidden_size, 1)
            self.sigmoid = torch.nn.Sigmoid()
            self.dropout = torch.nn.Dropout(dropout)
            
        def forward(self, x):
            x = self.fc1(x)
            x = self.dropout(x)
            x = self.relu(x)
            x = self.fc2(x)
            x = self.dropout(x)
            x = self.relu(x)
            x = self.fc3(x)
            x = self.dropout(x)
            x = self.relu(x)
            x = self.fc4(x)
            x = self.dropout(x)
            x = self.relu(x)
            x = self.fc5(x)
            x = self.dropout(x)
            x = self.relu(x)
            output = self.fc_out(x)
            output = self.sigmoid(output)
            return output

# %%
data = pd.read_csv('/Users/nkerstingadxnet.com/Documents/Higgs/orig/atlas-higgs-challenge-2014-v2.csv')
data['Binary_Label'] = data['Label'].map({'s':1,'b':0})

# %%
nonphi_columns = [c for c in data.columns if "phi" in c]
for col in nonphi_columns:
    data.drop(col, axis=1, inplace=True)
data.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_leading_pt  \
# 0               3.064      41.928  ...              67.435
# 1               3.473       2.078  ...              46.226
# 2               3.148       9.336  ...              44.251
# 3               3.310       0.414  ...            -999.000
# 4               3.891      16.405  ...            -999.000
#
#    PRI_jet_leading_eta  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 0                2.150                 46.062                    1.24
# 1                0.725               -999.000                 -999.00
# 2                2.053               -999.000                 -999.00
# 3             -999.000               -999.000                 -999.00
# 4             -999.000               -999.000                 -999.00
#
#    PRI_jet_all_pt    Weight  Label  KaggleSet  KaggleWeight  Binary_Label
# 0         113.497  0.000814      s          t      0.002653             1
# 1          46.226  0.681042      b          t      2.233584             0
# 2          44.251  0.715742      b          t      2.347389             0
# 3          -0.000  1.660654      b          t      5.446378             0
# 4           0.000  1.904263      b          t      6.245333             0
#
# [5 rows x 30 columns]

# %%
# now replace all the '-999' values with NULL so we can properly handle them
#nulled_data = data.replace(-999.0, np.nan)
nulled_data = data.replace(-999.0, 0)
train_data = nulled_data.loc[nulled_data['KaggleSet'] == 't'].copy(deep=True)
public_test_data = nulled_data.loc[nulled_data['KaggleSet'] == 'b'].copy(deep=True)
private_test_data = nulled_data.loc[nulled_data['KaggleSet'] == 'v'].copy(deep=True)

# %%
orig_train_data = train_data.copy(deep=True)
orig_public_test_data = public_test_data.copy(deep=True)
orig_private_test_data = private_test_data.copy(deep=True)


# now replace the null values with column averages
train_data.drop('EventId', axis=1, inplace=True)
train_data.drop('Label', axis=1, inplace=True)
train_data.drop('Binary_Label', axis=1, inplace=True)
train_data.drop('Weight', axis=1, inplace=True)
train_data.drop('KaggleWeight', axis=1, inplace=True)
train_data.drop('KaggleSet', axis=1, inplace=True)
for col in train_data:
    train_data[col].fillna(train_data[col].mean(), inplace=True)
#train_data.isnull().sum()


public_test_data.drop('EventId', axis=1, inplace=True)
public_test_data.drop('Label', axis=1, inplace=True)
public_test_data.drop('Binary_Label', axis=1, inplace=True)
public_test_data.drop('Weight', axis=1, inplace=True)
public_test_data.drop('KaggleWeight', axis=1, inplace=True)
public_test_data.drop('KaggleSet', axis=1, inplace=True)
for col in public_test_data:
    public_test_data[col].fillna(public_test_data[col].mean(), inplace=True)
#public_test_data.isnull().sum()


private_test_data.drop('EventId', axis=1, inplace=True)
private_test_data.drop('Label', axis=1, inplace=True)
private_test_data.drop('Binary_Label', axis=1, inplace=True)
private_test_data.drop('Weight', axis=1, inplace=True)
private_test_data.drop('KaggleWeight', axis=1, inplace=True)
private_test_data.drop('KaggleSet', axis=1, inplace=True)
for col in private_test_data:
    private_test_data[col].fillna(private_test_data[col].mean(), inplace=True)
#private_test_data.isnull().sum()

# %%
# now let's normalize
normed_train_data = (train_data - train_data.min())/(train_data.max() - train_data.min())

normed_public_test_data = (public_test_data - public_test_data.min())/(public_test_data.max() - public_test_data.min())

normed_private_test_data = (private_test_data - private_test_data.min())/(private_test_data.max() - private_test_data.min())

# %%
normed_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 250000 entries, 0 to 249999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   DER_mass_MMC                 250000 non-null  float64
#  1   DER_mass_transverse_met_lep  250000 non-null  float64
#  2   DER_mass_vis                 250000 non-null  float64
#  3   DER_pt_h                     250000 non-null  float64
#  4   DER_deltaeta_jet_jet         250000 non-null  float64
#  5   DER_mass_jet_jet             250000 non-null  float64
#  6   DER_prodeta_jet_jet          250000 non-null  float64
#  7   DER_deltar_tau_lep           250000 non-null  float64
#  8   DER_pt_tot                   250000 non-null  float64
#  9   DER_sum_pt                   250000 non-null  float64
#  10  DER_pt_ratio_lep_tau         250000 non-null  float64
#  11  DER_lep_eta_centrality       250000 non-null  float64
#  12  PRI_tau_pt                   250000 non-null  float64
#  13  PRI_tau_eta                  250000 non-null  float64
#  14  PRI_lep_pt                   250000 non-null  float64
#  15  PRI_lep_eta                  250000 non-null  float64
#  16  PRI_met                      250000 non-null  float64
#  17  PRI_met_sumet                250000 non-null  float64
#  18  PRI_jet_num                  250000 non-null  float64
#  19  PRI_jet_leading_pt           250000 non-null  float64
#  20  PRI_jet_leading_eta          250000 non-null  float64
#  21  PRI_jet_subleading_pt        250000 non-null  float64
#  22  PRI_jet_subleading_eta       250000 non-null  float64
#  23  PRI_jet_all_pt               250000 non-null  float64
# dtypes: float64(24)
# memory usage: 47.7 MB

# %%
train_input_data = []
for i in range(len(orig_train_data)):
   train_input_data.append([torch.tensor(normed_train_data.iloc[i], dtype=torch.float), torch.tensor(orig_train_data['Binary_Label'].iloc[i] , dtype=torch.float)])
valid_input_data = []
for i in range(len(orig_public_test_data)):
   valid_input_data.append([torch.tensor(normed_public_test_data.iloc[i], dtype=torch.float), torch.tensor(orig_public_test_data['Binary_Label'].iloc[i] , dtype=torch.float)])

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(train_input_data, batch_size=128, shuffle=True)
valid_dataloader = DataLoader(valid_input_data, batch_size=128, shuffle=True)

# %%
model = Feedforward(24, 600, 0.05)
criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)

# %%
import time
import copy
from datetime import datetime

now = datetime.now()
dt_string = now.strftime("%d%m%Y%H%M%S")
logfile = open(dt_string + ".log",'w')

start_time = time.time()
epoch = 20
maxvalcount = 5
minval_loss = np.inf
valcount = maxvalcount
best_model = model
for epoch in range(epoch):
    print("EPOCH: ", epoch)
    model.train()
    for i,batch in enumerate(train_dataloader):
        inputs, output = batch
        optimizer.zero_grad()
        # Forward pass
        y_pred = model(inputs)
        # Compute Loss
        loss = criterion(y_pred.squeeze(), output)
        if i % 100 == 0:
            logstring = 'Batch {}: train loss: {}'.format(i, loss.item())
            print(logstring)
            logfile.write(logstring + '\n')
        # Backward pass
        loss.backward()
        optimizer.step()
    # compute validation loss
    model.eval()
    with torch.set_grad_enabled(False):
        val_loss = 0
        for i,batch in enumerate(valid_dataloader):
            inputs, output = batch
            y_pred = model(inputs)
            y_pred = model(inputs)
            loss = criterion(y_pred.squeeze(), output)
            val_loss += loss
            if i % 100 == 0:
                logstring = 'Validation Batch {}: loss: {}'.format(i, loss.item())
                print(logstring)
                logfile.write(logstring + '\n')
        avg_val_loss = val_loss / len(valid_dataloader)
        valstring = f"AVERAGE BATCH VAL LOSS = {avg_val_loss}"
        print(valstring)
        logfile.write(valstring + '\n')
    if avg_val_loss < minval_loss:
        minval_loss = avg_val_loss
        best_model = copy.deepcopy(model)
        valcount = maxvalcount
    else:
        valcount -= 1
    if valcount == 0:
        endmsg = f"Validation Loss failed to decrease in {maxvalcount} epochs, exiting with best model, val loss = {minval_loss}"
        print(endmsg)
        logfile.write(endmsg + '\n')
        break

end_time = time.time()
timestring = f"Time elapsed in training: {end_time - start_time} seconds"
print(timestring)
logfile.write(timestring + '\n')
# Out:
# EPOCH:  0
# Batch 0: train loss: 0.6939132809638977
# Batch 100: train loss: 0.6632571816444397
# Batch 200: train loss: 0.6574290990829468
# Batch 300: train loss: 0.6586119532585144
# Batch 400: train loss: 0.6301531791687012
# Batch 500: train loss: 0.6532390117645264
# Batch 600: train loss: 0.6441534757614136
# Batch 700: train loss: 0.6342890858650208
# Batch 800: train loss: 0.619281530380249
# Batch 900: train loss: 0.658097505569458
# Batch 1000: train loss: 0.6330832242965698
# Batch 1100: train loss: 0.6532653570175171
# Batch 1200: train loss: 0.6583679914474487
# Batch 1300: train loss: 0.6275248527526855
# Batch 1400: train loss: 0.6527047753334045
# Batch 1500: train loss: 0.668343186378479
# Batch 1600: train loss: 0.6531516909599304
# Batch 1700: train loss: 0.6380125284194946
# Batch 1800: train loss: 0.6936875581741333
# Batch 1900: train loss: 0.6378073692321777
# Validation Batch 0: loss: 0.6578571200370789
# Validation Batch 100: loss: 0.6575490236282349
# Validation Batch 200: loss: 0.6531433463096619
# Validation Batch 300: loss: 0.6734303832054138
# Validation Batch 400: loss: 0.6171377301216125
# Validation Batch 500: loss: 0.6469914317131042
# Validation Batch 600: loss: 0.6312107443809509
# Validation Batch 700: loss: 0.6166122555732727
# AVERAGE BATCH VAL LOSS = 0.6402783393859863
# EPOCH:  1
# Batch 0: train loss: 0.636498749256134
# Batch 100: train loss: 0.6679003238677979
# Batch 200: train loss: 0.6787561178207397
# Batch 300: train loss: 0.6165451407432556
# Batch 400: train loss: 0.6372774243354797
# Batch 500: train loss: 0.6517091989517212
# Batch 600: train loss: 0.5913922786712646
# Batch 700: train loss: 0.6060289740562439
# Batch 800: train loss: 0.6108975410461426
# Batch 900: train loss: 0.6420398354530334
# Batch 1000: train loss: 0.6377556920051575
# Batch 1100: train loss: 0.6830945611000061
# Batch 1200: train loss: 0.6614872813224792
# Batch 1300: train loss: 0.5940958857536316
# Batch 1400: train loss: 0.6416032910346985
# Batch 1500: train loss: 0.6710430979728699
# Batch 1600: train loss: 0.666130781173706
# Batch 1700: train loss: 0.6465094089508057
# Batch 1800: train loss: 0.6433191299438477
# Batch 1900: train loss: 0.6294386982917786
# Validation Batch 0: loss: 0.6343711018562317
# Validation Batch 100: loss: 0.6382949948310852
# Validation Batch 200: loss: 0.6626817584037781
# Validation Batch 300: loss: 0.6803187131881714
# Validation Batch 400: loss: 0.6511983871459961
# Validation Batch 500: loss: 0.6505488157272339
# Validation Batch 600: loss: 0.68340665102005
# Validation Batch 700: loss: 0.6598861813545227
# AVERAGE BATCH VAL LOSS = 0.6368321776390076
# EPOCH:  2
# Batch 0: train loss: 0.6308090686798096
# Batch 100: train loss: 0.6409876346588135
# Batch 200: train loss: 0.6277504563331604
# Batch 300: train loss: 0.6651208996772766
# Batch 400: train loss: 0.6060817241668701
# Batch 500: train loss: 0.6438527703285217
# Batch 600: train loss: 0.5819820761680603
# Batch 700: train loss: 0.6441792249679565
# Batch 800: train loss: 0.6404027938842773
# Batch 900: train loss: 0.648664116859436
# Batch 1000: train loss: 0.6496593356132507
# Batch 1100: train loss: 0.6165570020675659
# Batch 1200: train loss: 0.6512883305549622
# Batch 1300: train loss: 0.6695539951324463
# Batch 1400: train loss: 0.6759926676750183
# Batch 1500: train loss: 0.638474702835083
# Batch 1600: train loss: 0.6329284906387329
# Batch 1700: train loss: 0.6659663915634155
# Batch 1800: train loss: 0.6410823464393616
# Batch 1900: train loss: 0.6160322427749634
# Validation Batch 0: loss: 0.615014374256134
# Validation Batch 100: loss: 0.6217911839485168
# Validation Batch 200: loss: 0.5983001589775085
# Validation Batch 300: loss: 0.6302312612533569
# Validation Batch 400: loss: 0.6313604712486267
# Validation Batch 500: loss: 0.5939302444458008
# Validation Batch 600: loss: 0.6032297015190125
# Validation Batch 700: loss: 0.6432451009750366
# AVERAGE BATCH VAL LOSS = 0.6235103607177734
# EPOCH:  3
# Batch 0: train loss: 0.6701692938804626
# Batch 100: train loss: 0.6284001469612122
# Batch 200: train loss: 0.6527963280677795
# Batch 300: train loss: 0.6133252382278442
# Batch 400: train loss: 0.6152321696281433
# Batch 500: train loss: 0.6661854386329651
# Batch 600: train loss: 0.6169856190681458
# Batch 700: train loss: 0.6136068105697632
# Batch 800: train loss: 0.5964699983596802
# Batch 900: train loss: 0.6249674558639526
# Batch 1000: train loss: 0.6195567846298218
# Batch 1100: train loss: 0.6248078942298889
# Batch 1200: train loss: 0.6597120761871338
# Batch 1300: train loss: 0.6120197176933289
# Batch 1400: train loss: 0.5941612124443054
# Batch 1500: train loss: 0.5933687686920166
# Batch 1600: train loss: 0.6408771872520447
# Batch 1700: train loss: 0.6191666722297668
# Batch 1800: train loss: 0.57570880651474
# Batch 1900: train loss: 0.5867123603820801
# Validation Batch 0: loss: 0.5939825773239136
# Validation Batch 100: loss: 0.6431149840354919
# Validation Batch 200: loss: 0.5968583226203918
# Validation Batch 300: loss: 0.618872344493866
# Validation Batch 400: loss: 0.5276168584823608
# Validation Batch 500: loss: 0.635736882686615
# Validation Batch 600: loss: 0.6019172072410583
# Validation Batch 700: loss: 0.5998831987380981
# AVERAGE BATCH VAL LOSS = 0.6054167747497559
# EPOCH:  4
# Batch 0: train loss: 0.5866206884384155
# Batch 100: train loss: 0.5725111961364746
# Batch 200: train loss: 0.5741884112358093
# Batch 300: train loss: 0.6002553701400757
# Batch 400: train loss: 0.5885365605354309
# Batch 500: train loss: 0.6107826828956604
# Batch 600: train loss: 0.5882990956306458
# Batch 700: train loss: 0.566827118396759
# Batch 800: train loss: 0.5875768065452576
# Batch 900: train loss: 0.6069451570510864
# Batch 1000: train loss: 0.5452995300292969
# Batch 1100: train loss: 0.6009621024131775
# Batch 1200: train loss: 0.5580244660377502
# Batch 1300: train loss: 0.6154254078865051
# Batch 1400: train loss: 0.5620813369750977
# Batch 1500: train loss: 0.5313740372657776
# Batch 1600: train loss: 0.6746658086776733
# Batch 1700: train loss: 0.573013424873352
# Batch 1800: train loss: 0.5115280747413635
# Batch 1900: train loss: 0.6417996287345886
# Validation Batch 0: loss: 0.574640691280365
# Validation Batch 100: loss: 0.608249843120575
# Validation Batch 200: loss: 0.5764776468276978
# Validation Batch 300: loss: 0.538425624370575
# Validation Batch 400: loss: 0.6146813035011292
# Validation Batch 500: loss: 0.5978070497512817
# Validation Batch 600: loss: 0.5732914805412292
# Validation Batch 700: loss: 0.5746453404426575
# AVERAGE BATCH VAL LOSS = 0.574627161026001
# EPOCH:  5
# Batch 0: train loss: 0.5738878846168518
# Batch 100: train loss: 0.5722362399101257
# Batch 200: train loss: 0.6268540024757385
# Batch 300: train loss: 0.5321847200393677
# Batch 400: train loss: 0.5210183262825012
# Batch 500: train loss: 0.5768179893493652
# Batch 600: train loss: 0.505236804485321
# Batch 700: train loss: 0.5360682010650635
# Batch 800: train loss: 0.5190253853797913
# Batch 900: train loss: 0.5791813135147095
# Batch 1000: train loss: 0.5260604023933411
# Batch 1100: train loss: 0.47992637753486633
# Batch 1200: train loss: 0.5659794807434082
# Batch 1300: train loss: 0.4739803373813629
# Batch 1400: train loss: 0.5138710737228394
# Batch 1500: train loss: 0.513181209564209
# Batch 1600: train loss: 0.5087588429450989
# Batch 1700: train loss: 0.5269374251365662
# Batch 1800: train loss: 0.4246940016746521
# Batch 1900: train loss: 0.4853856861591339
# Validation Batch 0: loss: 0.48666030168533325
# Validation Batch 100: loss: 0.5642277598381042
# Validation Batch 200: loss: 0.5346595644950867
# Validation Batch 300: loss: 0.5701654553413391
# Validation Batch 400: loss: 0.5579587817192078
# Validation Batch 500: loss: 0.5622687339782715
# Validation Batch 600: loss: 0.5168620944023132
# Validation Batch 700: loss: 0.5543766617774963
# AVERAGE BATCH VAL LOSS = 0.5594287514686584
# EPOCH:  6
# Batch 0: train loss: 0.5063467025756836
# Batch 100: train loss: 0.5421237945556641
# Batch 200: train loss: 0.4620315730571747
# Batch 300: train loss: 0.47842395305633545
# Batch 400: train loss: 0.5075494647026062
# Batch 500: train loss: 0.469528466463089
# Batch 600: train loss: 0.4806252717971802
# Batch 700: train loss: 0.41804513335227966
# Batch 800: train loss: 0.5365164875984192
# Batch 900: train loss: 0.48326215147972107
# Batch 1000: train loss: 0.46592196822166443
# Batch 1100: train loss: 0.4880281984806061
# Batch 1200: train loss: 0.4903481602668762
# Batch 1300: train loss: 0.49201956391334534
# Batch 1400: train loss: 0.43688681721687317
# Batch 1500: train loss: 0.442095547914505
# Batch 1600: train loss: 0.5520511269569397
# Batch 1700: train loss: 0.4940251410007477
# Batch 1800: train loss: 0.510895848274231
# Batch 1900: train loss: 0.46572715044021606
# Validation Batch 0: loss: 0.49045148491859436
# Validation Batch 100: loss: 0.6170564293861389
# Validation Batch 200: loss: 0.509824812412262
# Validation Batch 300: loss: 0.5237995982170105
# Validation Batch 400: loss: 0.48953890800476074
# Validation Batch 500: loss: 0.45610296726226807
# Validation Batch 600: loss: 0.48877838253974915
# Validation Batch 700: loss: 0.6119838356971741
# AVERAGE BATCH VAL LOSS = 0.5265254974365234
# EPOCH:  7
# Batch 0: train loss: 0.48958754539489746
# Batch 100: train loss: 0.4965895414352417
# Batch 200: train loss: 0.4476437568664551
# Batch 300: train loss: 0.5410751700401306
# Batch 400: train loss: 0.425415962934494
# Batch 500: train loss: 0.4822673797607422
# Batch 600: train loss: 0.500556230545044
# Batch 700: train loss: 0.4929511845111847
# Batch 800: train loss: 0.5382097363471985
# Batch 900: train loss: 0.5321594476699829
# Batch 1000: train loss: 0.4473347067832947
# Batch 1100: train loss: 0.5018389821052551
# Batch 1200: train loss: 0.46440374851226807
# Batch 1300: train loss: 0.5729731917381287
# Batch 1400: train loss: 0.46811726689338684
# Batch 1500: train loss: 0.4318336844444275
# Batch 1600: train loss: 0.4930556118488312
# Batch 1700: train loss: 0.5001241564750671
# Batch 1800: train loss: 0.5957030057907104
# Batch 1900: train loss: 0.4608987271785736
# Validation Batch 0: loss: 0.468028724193573
# Validation Batch 100: loss: 0.43093064427375793
# Validation Batch 200: loss: 0.533608078956604
# Validation Batch 300: loss: 0.3892682194709778
# Validation Batch 400: loss: 0.4740953743457794
# Validation Batch 500: loss: 0.4393084943294525
# Validation Batch 600: loss: 0.5103946328163147
# Validation Batch 700: loss: 0.41235023736953735
# AVERAGE BATCH VAL LOSS = 0.4621644616127014
# EPOCH:  8
# Batch 0: train loss: 0.4784156382083893
# Batch 100: train loss: 0.5627471804618835
# Batch 200: train loss: 0.5482072234153748
# Batch 300: train loss: 0.4586794078350067
# Batch 400: train loss: 0.42024844884872437
# Batch 500: train loss: 0.3638882637023926
# Batch 600: train loss: 0.43948420882225037
# Batch 700: train loss: 0.48405423760414124
# Batch 800: train loss: 0.46213987469673157
# Batch 900: train loss: 0.5104015469551086
# Batch 1000: train loss: 0.4475244879722595
# Batch 1100: train loss: 0.4968124032020569
# Batch 1200: train loss: 0.466838002204895
# Batch 1300: train loss: 0.4373718202114105
# Batch 1400: train loss: 0.42012616991996765
# Batch 1500: train loss: 0.4344780445098877
# Batch 1600: train loss: 0.4593852460384369
# Batch 1700: train loss: 0.5369386076927185
# Batch 1800: train loss: 0.5123443007469177
# Batch 1900: train loss: 0.503262996673584
# Validation Batch 0: loss: 0.6636623740196228
# Validation Batch 100: loss: 0.7476933002471924
# Validation Batch 200: loss: 0.5669113993644714
# Validation Batch 300: loss: 0.7186528444290161
# Validation Batch 400: loss: 0.6165364980697632
# Validation Batch 500: loss: 0.6645806431770325
# Validation Batch 600: loss: 0.6377452611923218
# Validation Batch 700: loss: 0.5440930128097534
# AVERAGE BATCH VAL LOSS = 0.6832500100135803
# EPOCH:  9
# Batch 0: train loss: 0.5628508925437927
# Batch 100: train loss: 0.45884957909584045
# Batch 200: train loss: 0.43216198682785034
# Batch 300: train loss: 0.5072132349014282
# Batch 400: train loss: 0.4711016118526459
# Batch 500: train loss: 0.448455810546875
# Batch 600: train loss: 0.5173675417900085
# Batch 700: train loss: 0.4823020100593567
# Batch 800: train loss: 0.43295252323150635
# Batch 900: train loss: 0.4792426824569702
# Batch 1000: train loss: 0.46808281540870667
# Batch 1100: train loss: 0.47781115770339966
# Batch 1200: train loss: 0.4109609127044678
# Batch 1300: train loss: 0.5179955959320068
# Batch 1400: train loss: 0.4629933536052704
# Batch 1500: train loss: 0.47168228030204773
# Batch 1600: train loss: 0.3830479681491852
# Batch 1700: train loss: 0.45888569951057434
# Batch 1800: train loss: 0.4015432894229889
# Batch 1900: train loss: 0.3996541500091553
# Validation Batch 0: loss: 0.45592331886291504
# Validation Batch 100: loss: 0.4723268151283264
# Validation Batch 200: loss: 0.5018904209136963
# Validation Batch 300: loss: 0.38446009159088135
# Validation Batch 400: loss: 0.40863898396492004
# Validation Batch 500: loss: 0.5265465378761292
# Validation Batch 600: loss: 0.4415191113948822
# Validation Batch 700: loss: 0.42745888233184814
# AVERAGE BATCH VAL LOSS = 0.45313888788223267
# EPOCH:  10
# Batch 0: train loss: 0.458010196685791
# Batch 100: train loss: 0.4604473412036896
# Batch 200: train loss: 0.44657623767852783
# Batch 300: train loss: 0.38773706555366516
# Batch 400: train loss: 0.4843730926513672
# Batch 500: train loss: 0.4938097596168518
# Batch 600: train loss: 0.38686391711235046
# Batch 700: train loss: 0.5138345956802368
# Batch 800: train loss: 0.4708997905254364
# Batch 900: train loss: 0.42722997069358826
# Batch 1000: train loss: 0.5007351040840149
# Batch 1100: train loss: 0.4788270890712738
# Batch 1200: train loss: 0.44666725397109985
# Batch 1300: train loss: 0.45111048221588135
# Batch 1400: train loss: 0.38053449988365173
# Batch 1500: train loss: 0.404160737991333
# Batch 1600: train loss: 0.43699100613594055
# Batch 1700: train loss: 0.4136493504047394
# Batch 1800: train loss: 0.4396309554576874
# Batch 1900: train loss: 0.41711312532424927
# Validation Batch 0: loss: 0.36817431449890137
# Validation Batch 100: loss: 0.45956915616989136
# Validation Batch 200: loss: 0.4480535387992859
# Validation Batch 300: loss: 0.3908202350139618
# Validation Batch 400: loss: 0.44894349575042725
# Validation Batch 500: loss: 0.3733117878437042
# Validation Batch 600: loss: 0.3897104859352112
# Validation Batch 700: loss: 0.40135154128074646
# AVERAGE BATCH VAL LOSS = 0.424165815114975
# EPOCH:  11
# Batch 0: train loss: 0.4759661853313446
# Batch 100: train loss: 0.3622056841850281
# Batch 200: train loss: 0.40005552768707275
# Batch 300: train loss: 0.3585888743400574
# Batch 400: train loss: 0.49648240208625793
# Batch 500: train loss: 0.47915107011795044
# Batch 600: train loss: 0.42635011672973633
# Batch 700: train loss: 0.4648614525794983
# Batch 800: train loss: 0.3749103248119354
# Batch 900: train loss: 0.4006442129611969
# Batch 1000: train loss: 0.4293658137321472
# Batch 1100: train loss: 0.3562605381011963
# Batch 1200: train loss: 0.4046543836593628
# Batch 1300: train loss: 0.35488709807395935
# Batch 1400: train loss: 0.4120701551437378
# Batch 1500: train loss: 0.4170248210430145
# Batch 1600: train loss: 0.4377749264240265
# Batch 1700: train loss: 0.4627574384212494
# Batch 1800: train loss: 0.3810923397541046
# Batch 1900: train loss: 0.3637530207633972
# Validation Batch 0: loss: 0.6128792762756348
# Validation Batch 100: loss: 0.4856666326522827
# Validation Batch 200: loss: 0.463510662317276
# Validation Batch 300: loss: 0.5285910367965698
# Validation Batch 400: loss: 0.5774332880973816
# Validation Batch 500: loss: 0.5343694090843201
# Validation Batch 600: loss: 0.4801754057407379
# Validation Batch 700: loss: 0.5497747659683228
# AVERAGE BATCH VAL LOSS = 0.5230205059051514
# EPOCH:  12
# Batch 0: train loss: 0.3727358281612396
# Batch 100: train loss: 0.40021300315856934
# Batch 200: train loss: 0.45065000653266907
# Batch 300: train loss: 0.30780187249183655
# Batch 400: train loss: 0.43323108553886414
# Batch 500: train loss: 0.4112323224544525
# Batch 600: train loss: 0.4513200521469116
# Batch 700: train loss: 0.3496719300746918
# Batch 800: train loss: 0.42724883556365967
# Batch 900: train loss: 0.3824675679206848
# Batch 1000: train loss: 0.43395811319351196
# Batch 1100: train loss: 0.5212346315383911
# Batch 1200: train loss: 0.43154728412628174
# Batch 1300: train loss: 0.5183247327804565
# Batch 1400: train loss: 0.4407848119735718
# Batch 1500: train loss: 0.36978209018707275
# Batch 1600: train loss: 0.3624088764190674
# Batch 1700: train loss: 0.3184235692024231
# Batch 1800: train loss: 0.4758217930793762
# Batch 1900: train loss: 0.4718932509422302
# Validation Batch 0: loss: 0.5018814206123352
# Validation Batch 100: loss: 0.5286015272140503
# Validation Batch 200: loss: 0.6085519790649414
# Validation Batch 300: loss: 0.4730319380760193
# Validation Batch 400: loss: 0.6211289763450623
# Validation Batch 500: loss: 0.4932243227958679
# Validation Batch 600: loss: 0.5452737212181091
# Validation Batch 700: loss: 0.514356255531311
# AVERAGE BATCH VAL LOSS = 0.555183470249176
# EPOCH:  13
# Batch 0: train loss: 0.36356866359710693
# Batch 100: train loss: 0.4840329587459564
# Batch 200: train loss: 0.3349227011203766
# Batch 300: train loss: 0.4521879255771637
# Batch 400: train loss: 0.4488215744495392
# Batch 500: train loss: 0.3475363254547119
# Batch 600: train loss: 0.48818737268447876
# Batch 700: train loss: 0.3836144208908081
# Batch 800: train loss: 0.4435311555862427
# Batch 900: train loss: 0.42256781458854675
# Batch 1000: train loss: 0.40732720494270325
# Batch 1100: train loss: 0.4263036847114563
# Batch 1200: train loss: 0.39793089032173157
# Batch 1300: train loss: 0.4901430904865265
# Batch 1400: train loss: 0.4009093642234802
# Batch 1500: train loss: 0.38082998991012573
# Batch 1600: train loss: 0.5053346753120422
# Batch 1700: train loss: 0.4362855553627014
# Batch 1800: train loss: 0.367319256067276
# Batch 1900: train loss: 0.42633646726608276
# Validation Batch 0: loss: 0.4884609878063202
# Validation Batch 100: loss: 0.45434629917144775
# Validation Batch 200: loss: 0.4259060025215149
# Validation Batch 300: loss: 0.4379153549671173
# Validation Batch 400: loss: 0.4142705500125885
# Validation Batch 500: loss: 0.41880935430526733
# Validation Batch 600: loss: 0.4672296345233917
# Validation Batch 700: loss: 0.36120831966400146
# AVERAGE BATCH VAL LOSS = 0.4426349997520447
# EPOCH:  14
# Batch 0: train loss: 0.3533109724521637
# Batch 100: train loss: 0.4138883948326111
# Batch 200: train loss: 0.3504193127155304
# Batch 300: train loss: 0.41671091318130493
# Batch 400: train loss: 0.4663322865962982
# Batch 500: train loss: 0.4373961389064789
# Batch 600: train loss: 0.372782826423645
# Batch 700: train loss: 0.34963321685791016
# Batch 800: train loss: 0.4945603907108307
# Batch 900: train loss: 0.37448301911354065
# Batch 1000: train loss: 0.34676170349121094
# Batch 1100: train loss: 0.3457266688346863
# Batch 1200: train loss: 0.38972705602645874
# Batch 1300: train loss: 0.35263174772262573
# Batch 1400: train loss: 0.4122157394886017
# Batch 1500: train loss: 0.3717619776725769
# Batch 1600: train loss: 0.37485113739967346
# Batch 1700: train loss: 0.43704745173454285
# Batch 1800: train loss: 0.4501538872718811
# Batch 1900: train loss: 0.3687339425086975
# Validation Batch 0: loss: 0.44385361671447754
# Validation Batch 100: loss: 0.3780762851238251
# Validation Batch 200: loss: 0.36626872420310974
# Validation Batch 300: loss: 0.4501139223575592
# Validation Batch 400: loss: 0.377727746963501
# Validation Batch 500: loss: 0.4500604271888733
# Validation Batch 600: loss: 0.4281102120876312
# Validation Batch 700: loss: 0.4613187611103058
# AVERAGE BATCH VAL LOSS = 0.40851160883903503
# EPOCH:  15
# Batch 0: train loss: 0.5358069539070129
# Batch 100: train loss: 0.4104684889316559
# Batch 200: train loss: 0.38897866010665894
# Batch 300: train loss: 0.44086337089538574
# Batch 400: train loss: 0.4764190912246704
# Batch 500: train loss: 0.4260413944721222
# Batch 600: train loss: 0.4895777702331543
# Batch 700: train loss: 0.5951675176620483
# Batch 800: train loss: 0.41857028007507324
# Batch 900: train loss: 0.3463840186595917
# Batch 1000: train loss: 0.3504120111465454
# Batch 1100: train loss: 0.37689879536628723
# Batch 1200: train loss: 0.363569051027298
# Batch 1300: train loss: 0.41459932923316956
# Batch 1400: train loss: 0.44008535146713257
# Batch 1500: train loss: 0.3353409171104431
# Batch 1600: train loss: 0.45795831084251404
# Batch 1700: train loss: 0.3921886682510376
# Batch 1800: train loss: 0.48760905861854553
# Batch 1900: train loss: 0.4144359827041626
# Validation Batch 0: loss: 0.3353607952594757
# Validation Batch 100: loss: 0.30998843908309937
# Validation Batch 200: loss: 0.4147709608078003
# Validation Batch 300: loss: 0.37573277950286865
# Validation Batch 400: loss: 0.38752487301826477
# Validation Batch 500: loss: 0.3200515806674957
# Validation Batch 600: loss: 0.39330053329467773
# Validation Batch 700: loss: 0.5419896841049194
# AVERAGE BATCH VAL LOSS = 0.4145258367061615
# EPOCH:  16
# Batch 0: train loss: 0.4264480173587799
# Batch 100: train loss: 0.4738657474517822
# Batch 200: train loss: 0.4146384596824646
# Batch 300: train loss: 0.34626469016075134
# Batch 400: train loss: 0.34671691060066223
# Batch 500: train loss: 0.3541005551815033
# Batch 600: train loss: 0.4018884301185608
# Batch 700: train loss: 0.44282248616218567
# Batch 800: train loss: 0.543525755405426
# Batch 900: train loss: 0.4298766255378723
# Batch 1000: train loss: 0.43463006615638733
# Batch 1100: train loss: 0.3621712625026703
# Batch 1200: train loss: 0.37050995230674744
# Batch 1300: train loss: 0.4605690538883209
# Batch 1400: train loss: 0.35933154821395874
# Batch 1500: train loss: 0.4516802132129669
# Batch 1600: train loss: 0.4455063045024872
# Batch 1700: train loss: 0.5266338586807251
# Batch 1800: train loss: 0.3568483889102936
# Batch 1900: train loss: 0.3991830050945282
# Validation Batch 0: loss: 0.4251648783683777
# Validation Batch 100: loss: 0.47702980041503906
# Validation Batch 200: loss: 0.4246535897254944
# Validation Batch 300: loss: 0.3580882251262665
# Validation Batch 400: loss: 0.4450996518135071
# Validation Batch 500: loss: 0.47319936752319336
# Validation Batch 600: loss: 0.4642690122127533
# Validation Batch 700: loss: 0.47863873839378357
# AVERAGE BATCH VAL LOSS = 0.42419877648353577
# EPOCH:  17
# Batch 0: train loss: 0.4355013072490692
# Batch 100: train loss: 0.5237617492675781
# Batch 200: train loss: 0.46407389640808105
# Batch 300: train loss: 0.4072732925415039
# Batch 400: train loss: 0.5206327438354492
# Batch 500: train loss: 0.4210589528083801
# Batch 600: train loss: 0.39670151472091675
# Batch 700: train loss: 0.4611307978630066
# Batch 800: train loss: 0.4018101394176483
# Batch 900: train loss: 0.36673450469970703
# Batch 1000: train loss: 0.4086587131023407
# Batch 1100: train loss: 0.34985196590423584
# Batch 1200: train loss: 0.3756173253059387
# Batch 1300: train loss: 0.4031238257884979
# Batch 1400: train loss: 0.43117526173591614
# Batch 1500: train loss: 0.46137022972106934
# Batch 1600: train loss: 0.4176854193210602
# Batch 1700: train loss: 0.4031411111354828
# Batch 1800: train loss: 0.48883530497550964
# Batch 1900: train loss: 0.3787132799625397
# Validation Batch 0: loss: 0.4882628917694092
# Validation Batch 100: loss: 0.4458337426185608
# Validation Batch 200: loss: 0.4718858003616333
# Validation Batch 300: loss: 0.5009572505950928
# Validation Batch 400: loss: 0.46891486644744873
# Validation Batch 500: loss: 0.49972373247146606
# Validation Batch 600: loss: 0.4255508482456207
# Validation Batch 700: loss: 0.40526342391967773
# AVERAGE BATCH VAL LOSS = 0.47516658902168274
# EPOCH:  18
# Batch 0: train loss: 0.38079947233200073
# Batch 100: train loss: 0.5113452076911926
# Batch 200: train loss: 0.4346693158149719
# Batch 300: train loss: 0.31386783719062805
# Batch 400: train loss: 0.4017876386642456
# Batch 500: train loss: 0.4447406530380249
# Batch 600: train loss: 0.427734375
# Batch 700: train loss: 0.3976721465587616
# Batch 800: train loss: 0.3660217523574829
# Batch 900: train loss: 0.33292707800865173
# Batch 1000: train loss: 0.4947342872619629
# Batch 1100: train loss: 0.38563814759254456
# Batch 1200: train loss: 0.3467128276824951
# Batch 1300: train loss: 0.3669794201850891
# Batch 1400: train loss: 0.3529011607170105
# Batch 1500: train loss: 0.425322562456131
# Batch 1600: train loss: 0.44235625863075256
# Batch 1700: train loss: 0.35742971301078796
# Batch 1800: train loss: 0.3821931481361389
# Batch 1900: train loss: 0.4415076971054077
# Validation Batch 0: loss: 0.4777832627296448
# Validation Batch 100: loss: 0.5275609493255615
# Validation Batch 200: loss: 0.5775328874588013
# Validation Batch 300: loss: 0.44893163442611694
# Validation Batch 400: loss: 0.5442298650741577
# Validation Batch 500: loss: 0.4758354127407074
# Validation Batch 600: loss: 0.5458776354789734
# Validation Batch 700: loss: 0.4865875542163849
# AVERAGE BATCH VAL LOSS = 0.4821699261665344
# EPOCH:  19
# Batch 0: train loss: 0.39293691515922546
# Batch 100: train loss: 0.321545273065567
# Batch 200: train loss: 0.35546061396598816
# Batch 300: train loss: 0.46820998191833496
# Batch 400: train loss: 0.3621624708175659
# Batch 500: train loss: 0.3851128816604614
# Batch 600: train loss: 0.46511557698249817
# Batch 700: train loss: 0.3772420287132263
# Batch 800: train loss: 0.3888138234615326
# Batch 900: train loss: 0.35250434279441833
# Batch 1000: train loss: 0.3030570447444916
# Batch 1100: train loss: 0.417118102312088
# Batch 1200: train loss: 0.3328879177570343
# Batch 1300: train loss: 0.39253440499305725
# Batch 1400: train loss: 0.44840794801712036
# Batch 1500: train loss: 0.39656755328178406
# Batch 1600: train loss: 0.41722556948661804
# Batch 1700: train loss: 0.3950056731700897
# Batch 1800: train loss: 0.395925372838974
# Batch 1900: train loss: 0.3629803955554962
# Validation Batch 0: loss: 0.4189511239528656
# Validation Batch 100: loss: 0.33250489830970764
# Validation Batch 200: loss: 0.3570936620235443
# Validation Batch 300: loss: 0.3662481904029846
# Validation Batch 400: loss: 0.36324185132980347
# Validation Batch 500: loss: 0.41968968510627747
# Validation Batch 600: loss: 0.3776662051677704
# Validation Batch 700: loss: 0.4533129334449768
# AVERAGE BATCH VAL LOSS = 0.4067927896976471
# Time elapsed in training: 5625.511304855347 seconds

# %%
torch.save(best_model, '/Users/nkerstingadxnet.com/Documents/Higgs/output/mlp.600.nophi.pt')

# %%
import math
def AMS(s, b):
    """ Approximate Median Significance defined as:
        AMS = sqrt(
                2 { (s + b + b_r) log[1 + (s/(b+b_r))] - s}
              )        
    where b_r = 10, b = background, s = signal, log is natural logarithm """
    
    br = 10.0
    radicand = 2 *( (s+b+br) * math.log (1.0 + s/(b+br)) -s)
    if radicand < 0:
        print('radicand is negative. Exiting')
        exit()
    else:
        return math.sqrt(radicand)

# %%
# Training performance
best_model.eval()
y_pred = best_model(torch.tensor(normed_train_data.values, dtype=torch.float)).tolist()
y_gold = orig_train_data['Label']
y_weight = orig_train_data['KaggleWeight']
s = 0
b = 0
tp = 0
fp = 0
for i,y in enumerate(y_pred):
    if y[0] > 0.5:
        if y_gold.iloc[i] == 's':
            s += y_weight.iloc[i]
            tp += 1
        else:
            b += y_weight.iloc[i]
            fp += 1
outstring = f"TRAINING: (S,B) = ({s:.3f},{b:.3f}), AMS={AMS(s,b):.3f}, Unweighted Precision = {tp/(tp+fp):.3f}"
print(outstring)
logfile.write(outstring + '\n')
# Out:
# TRAINING: (S,B) = (260.255,7055.661), AMS=3.077, Unweighted Precision = 0.889
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1s/blnhl5wx79b1ghnvdxcd8vy80000gp/T/ipykernel_85558/1640848982.py in <module>
#      18 outstring = f"TRAINING: (S,B) = ({s:.3f},{b:.3f}), AMS={AMS(s,b):.3f}, Unweighted Precision = {tp/(tp+fp):.3f}"
#      19 print(outstring)
# ---> 20 logfile.write(outstring + '\n')
#
# ValueError: I/O operation on closed file.

# %%
# Validation performance
y_pred = best_model(torch.tensor(normed_public_test_data.values, dtype=torch.float)).tolist()
y_gold = orig_public_test_data['Label']
y_weight = orig_public_test_data['KaggleWeight']
s = 0
b = 0
tp = 0
fp = 0
for i,y in enumerate(y_pred):
    if y[0] > 0.5:
        if y_gold.iloc[i] == 's':
            s += y_weight.iloc[i]
            tp += 1
        else:
            b += y_weight.iloc[i]
            fp += 1
outstring = f"VALID: (S,B) = ({s:.3f},{b:.3f}), AMS={AMS(s,b):.3f}, Unweighted Precision = {tp/(tp+fp):.3f}"
print(outstring)
logfile.write(outstring + '\n')
# Out:
# VALID: (S,B) = (427.961,23656.495), AMS=2.774, Unweighted Precision = 0.754
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1s/blnhl5wx79b1ghnvdxcd8vy80000gp/T/ipykernel_85558/1432329564.py in <module>
#      17 outstring = f"VALID: (S,B) = ({s:.3f},{b:.3f}), AMS={AMS(s,b):.3f}, Unweighted Precision = {tp/(tp+fp):.3f}"
#      18 print(outstring)
# ---> 19 logfile.write(outstring + '\n')
#
# ValueError: I/O operation on closed file.

# %%
# Test set performance
y_pred = best_model(torch.tensor(normed_private_test_data.values, dtype=torch.float)).tolist()
y_gold = orig_private_test_data['Label']
y_weight = orig_private_test_data['KaggleWeight']
s = 0
b = 0
tp = 0
fp = 0
for i,y in enumerate(y_pred):
    if y[0] > 0.5:
        if y_gold.iloc[i] == 's':
            s += y_weight.iloc[i]
            tp += 1
        else:
            b += y_weight.iloc[i]
            fp += 1
outstring = f"TEST: (S,B) = ({s:.3f},{b:.3f}), AMS={AMS(s,b):.3f}, Unweighted Precision = {tp/(tp+fp):.3f}"
print(outstring)
logfile.write(outstring + '\n')
# Out:
# TEST: (S,B) = (268.659,16633.524), AMS=2.077, Unweighted Precision = 0.754
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1s/blnhl5wx79b1ghnvdxcd8vy80000gp/T/ipykernel_85558/1554787232.py in <module>
#      17 outstring = f"TEST: (S,B) = ({s:.3f},{b:.3f}), AMS={AMS(s,b):.3f}, Unweighted Precision = {tp/(tp+fp):.3f}"
#      18 print(outstring)
# ---> 19 logfile.write(outstring + '\n')
#
# ValueError: I/O operation on closed file.

# %%
logfile.close()

# %%
np.inf
# Out:
# inf

# %%
1 < np.inf
# Out:
# True
